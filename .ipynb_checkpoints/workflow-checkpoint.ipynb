# %% [markdown]
# # Telco Customer Churn

# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as px
import time
import random

# %% [markdown]
# # EDA

# %%
train =  pd.read_csv('Data/train.xls')
train.shape
# Out:
# (7043, 21)

# %% [markdown]
# Look For NA Values

# %%
train.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# Zero NA values

# %% [markdown]
# Look for Duplicates

# %%
train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No Duplicates

# %% [markdown]
# Row Cardinality

# %%
train.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %% [markdown]
# 3 continous, 17 Categorical, plus Target and ID field

# %% [markdown]
# Data Types

# %%
train.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [raw]
# Will need to change some data types

# %%
train['Churn'].value_counts().plot.pie(shadow = True, explode = [0.05, 0.05],
                                      autopct = '%1.1f%%', textprops = {'fontsize':16}).set_title('Percentage Distribution of Churn Variable')
# Out:
# Text(0.5, 1.0, 'Percentage Distribution of Churn Variable')

# %% [markdown]
# Target is slightly skewed, may need to consider resampling

# %% [markdown]
# **Distribution of Continous Columns**

# %%
# convert TotalCharges to float
# some  values in TotalCharges contain empty strings
# replace them with '0'
train.loc[train['TotalCharges'].str.contains(' '), ['TotalCharges']] = '0'
train['TotalCharges'] = train['TotalCharges'].astype('float')

# %%
numCols = ['tenure', 'MonthlyCharges', 'TotalCharges']
for i in numCols:
    fig = px.histogram(train.sort_values(by = ['Churn'], ascending = False), x = i, color = 'Churn',
                       color_discrete_sequence = px.colors.qualitative.Vivid, marginal = 'box')
    fig.update_layout(
        bargap = .1,
        yaxis_title_text = 'Count'
    )
    fig.show()
# Out:
# <div>                            <div id="50218645-b54b-4a66-8a97-b27b8c341f9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50218645-b54b-4a66-8a97-b27b8c341f9e")) {                    Plotly.newPlot(                        "50218645-b54b-4a66-8a97-b27b8c341f9e",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=Yes<br>tenure=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Yes","marker":{"color":"rgb(229, 134, 6)","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":true,"x":[10,2,36,12,5,32,1,59,2,1,4,2,17,12,10,1,3,22,39,47,1,11,34,18,16,1,70,16,15,1,53,13,1,70,27,10,59,1,9,4,4,13,9,3,1,4,18,38,34,29,1,1,10,51,14,1,36,3,41,66,1,1,1,3,59,2,1,3,68,3,1,46,23,22,6,2,4,7,12,1
# ...
